# %% [markdown]
# ##### Finding the Largest or Smallest N Items

# %%
portfolio = [
{'name': 'IBM', 'shares': 100, 'price': 91.1},
{'name': 'AAPL', 'shares': 50, 'price': 543.22},
{'name': 'FB', 'shares': 200, 'price': 21.09},
{'name': 'HPQ', 'shares': 35, 'price': 31.75},
{'name': 'YHOO', 'shares': 45, 'price': 16.35},
{'name': 'ACME', 'shares': 75, 'price': 115.65}
]
portfolio
# Out:
# [{'name': 'IBM', 'price': 91.1, 'shares': 100},
#  {'name': 'AAPL', 'price': 543.22, 'shares': 50},
#  {'name': 'FB', 'price': 21.09, 'shares': 200},
#  {'name': 'HPQ', 'price': 31.75, 'shares': 35},
#  {'name': 'YHOO', 'price': 16.35, 'shares': 45},
#  {'name': 'ACME', 'price': 115.65, 'shares': 75}]

# %%
import heapq
cheap_items = heapq.nsmallest(3, portfolio, key = lambda s: s['price'])
cheap_items
# Out:
# [{'name': 'YHOO', 'price': 16.35, 'shares': 45},
#  {'name': 'FB', 'price': 21.09, 'shares': 200},
#  {'name': 'HPQ', 'price': 31.75, 'shares': 35}]

# %%
expensive_items = heapq.nlargest(3, portfolio, key= lambda s : s['price'])
expensive_items
# Out:
# [{'name': 'AAPL', 'price': 543.22, 'shares': 50},
#  {'name': 'ACME', 'price': 115.65, 'shares': 75},
#  {'name': 'IBM', 'price': 91.1, 'shares': 100}]

# %%
FILEPATH = r'/Users/NVishwakarma/Documents/PersonalProjects/Cookbook/Files/'
FILENAME = r'winemag-data_first150k.csv'
FILE = FILEPATH+FILENAME
FILE
# Out:
# '/Users/NVishwakarma/Documents/PersonalProjects/Cookbook/Files/winemag-data_first150k.csv'

# %%
import pandas as pd

df_winery = pd.read_csv(FILE)
df_winery.shape
# Out:
# (150930, 11)

# %%
df_winery.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
df_winery = df_winery.drop('Unnamed: 0', axis=1)
df_winery
# Out:
#             country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# ...

# %% [markdown]
# ##### Drop Duplicates

# %%
df_winery_clean = df_winery.drop_duplicates(keep='first')
df_winery_clean.shape
# Out:
# (97851, 10)

# %%
df_california_Napa = df_winery_clean[(df_winery_clean['province']=='California') & (df_winery_clean['region_2']=='Napa')]
df_california_Napa
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 16          US  This blockbuster, powerhouse of a wine suggest...
# 20          US  Heitz has made this stellar rosé from the rare...
# 47          US  Blended with 9% Malbec, 9% Cabernet Franc and ...
# 67          US  From the producer's monumental Atlas Peak vine...
# 69          US  A juiciness of cherry and vanilla spark the op...
# 70          US  Sweetened tannins highlight a depth of chocola...
# 77          US  Given four months in concrete egg, this is an ...
# 78          US  This wine over-delivers in quality for the pri...
# 87          US  From a multiplicity of vineyards, this wine wo...
# 89          US  A red Meritage driven by 73% Cabernet Sauvigno...
# 101         US  Brambly and herbal, this wine shows bright aci...
# 109         US  This is from a hillside estate vineyard and is...
# ...

# %% [markdown]
# ##### Napa California Wineries by rating points and price

# %%
df_california_Napa[['winery', 'points', 'price']]\
.groupby(['winery']).max()\
.sort_values(['points', 'price'], ascending=False)
# Out:
#                           points  price
# winery
# Cardinale                    100  300.0
# Sloan                        100  245.0
# Shafer                       100  230.0
# Harlan Estate                 99  500.0
# Colgin                        99  290.0
# Trefethen                     99  175.0
# David Arthur                  99  150.0
# BOND                          98  275.0
# Rubicon Estate                98  175.0
# The Maiden                    98  150.0
# Vine Cliff                    98  150.0
# Von Strasser                  98  135.0
# Coup de Foudre                98   95.0
# Yao Ming                      97  625.0
# Au Sommet                     97  250.0
# Joseph Phelps                 97  250.0
# Stag's Leap Wine Cellars      97  245.0
# Paul Hobbs                    97  235.0
# Diamond Creek                 97  200.0
# Alpha Omega                   97  195.0
# Ovid                          97  195.0
# Gandona                       97  190.0
# ...

# %%
df_winery_clean[df_winery_clean['province']=='California']\
.groupby(['points'])\
.max()\
.sort_values(by='price', ascending=False)
# Out:
#        country                                        description   price  \
# points
# 91          US  “Gas station” isn't necessarily the most attra...  2013.0
# 97          US  Without doubt this is a wine to cellar. It's m...   625.0
# 96          US  Young and succulent, this is fresh, with ripe ...   500.0
# 94          US  Zinfandel isn't ordinarily a wine you want to ...   500.0
# 95          US  Youthful tannins star in this young wine. The ...   450.0
# 98          US  This year's Matriarch is very similar to Harla...   350.0
# 93          US  Zin with a Pinot sensibility; it's bright, spi...   300.0
# 99          US  This is nearly perfect, a massive, monumental ...   290.0
# 86          US  ots of briary, brambly wild berry and cherry f...   275.0
# 92          US  “Califa” is a Native American word meaning the...   275.0
# 100         US  Tasted in a flight of great and famous Napa wi...   245.0
# 84          US  “The Three Young Ladies”––Viognier, Roussanne ...   225.0
# ...

# %%
df_california = df_winery_clean[(df_winery_clean['province']=='California') & (df_winery_clean['region_1']=='Stags Leap District')]#.groupby(['points']).max()
df_california[['points', 'description']].groupby(['points']).count()
# Out:
#         description
# points
# 82                3
# 84                3
# 85                3
# 86                4
# 87                7
# 88                7
# 89               12
# 90               18
# 91               15
# 92               20
# 93               18
# 94                7
# 95                7
# 96                4
# 97                2
# 100               1

# %% [markdown]
# ##### Get wineries with largest points

# %%
df_winery[['points']]
high_points = heapq.nlargest(5, df_winery[['points']])#, key= df_winery.apply(lambda s : df_winery[['points']]))
high_points
# Out:
# ['points']

# %%
df_winery[['description', 'points', 'designation', 'region_1', 'country']].duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 150900     True
# 150901     True
# 150902     True
# 150903     True
# 150904     True
# 150905     True
# 150906     True
# 150907     True
# 150908     True
# 150909     True
# 150910     True
# 150911     True
# 150912     True
# 150913     True
# 150914     True
# 150915     True
# 150916     True
# 150917     True
# 150918     True
# 150919     True
# 150920     True
# 150921     True
# 150922     True
# 150923     True
# ...

# %%
df_winery_clean[['description', 'price', 'points', 'designation', 'region_1','region_2', 'country']].sort_values(by="points", ascending=False)
# Out:
#                                               description   price  points  \
# 98647   A spectacular Pinot Noir, but a very young one...   100.0     100
# 92916   A perfect score has to be considered in the co...   215.0     100
# 24151   A perfect wine from a classic vintage, the 200...   460.0     100
# 19354   In a stunning lineup of Cayuse Syrahs, the En ...    65.0     100
# 19355   Not a Cellar Selection in the traditional sens...   300.0     100
# 111087  Thick as molasses and dark as caramelized brow...   210.0     100
# 26296   A wine that has created its own universe. It h...  1400.0     100
# 28954   This small, family-run estate in the heart of ...   195.0     100
# 2145    Full of ripe fruit, opulent and concentrated, ...   848.0     100
# 114272  Impossibly aromatic. Hard to imagine greater c...   245.0     100
# 89399   Tasted in a flight of great and famous Napa wi...   200.0     100
# 90439   There are incredible aromatics on this Caberne...   150.0      99
# ...

# %%
df_winery_clean.groupby('points').max()#, 'region_1', 'country', 'points'].max()
# Out:
#                                               description   price  \
# points
# 80      “Wine for Seafood” is a Trebbiano-based wine f...    80.0
# 81      “Wine for a new world” says the wine's tagline...   354.0
# 82      “Fronty” is an old Australian term for Muscat ...   150.0
# 83      “Pannobile” is a designation being used by Bur...   225.0
# 84      “The Three Young Ladies”––Viognier, Roussanne ...   225.0
# 85      “Pear” sums up the most obvious component of t...   320.0
# 86      “T” is a no-fuss Friulano (a native grape of n...   495.0
# 87      “Vecio Belo,” which is Venetian for “old” and ...   325.0
# 88      “Zéro Dosage” means just that; the resulting w...   325.0
# 89      “Vif” is a French word that loosely translates...   500.0
# 90      “Swan Song” indicates that this is the last vi...   535.0
# 91      “L'Homme Mort,” which is French for “the dead ...  2013.0
# 92      “Rhône times three” seems to be the code name ...   670.0
# ...
